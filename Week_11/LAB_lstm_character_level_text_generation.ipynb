# %% [markdown]
# # Character-level text generation with LSTM
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2015/06/15<br>
# **Last modified:** 2020/04/30<br>
# **Description:** Generate text from Nietzsche's writings with a character-level LSTM.

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to use a LSTM model to generate
# text character-by-character.
#
# At least 20 epochs are required before the generated text
# starts sounding locally coherent.
#
# It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %% [markdown]
# ## Setup

# %%
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import random
import io

# %% [markdown]
# ## Prepare the data

# %%
path = keras.utils.get_file(
    "nietzsche.txt", origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt"
)
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))

chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step
# 614400/600901 [==============================] - 1s 1us/step
# Corpus length: 600893
# Total chars: 56
# Number of sequences: 200285

# %% [markdown]
# ## Build the model: a single LSTM layer

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %% [markdown]
# ## Prepare the text sampling function

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Train the model

# %%
epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print()
# Out:
# 1565/1565 [==============================] - 29s 14ms/step - loss: 1.9073
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: "torily--"strong! strong! strong and mad!"
# ...Generated:   and a man and artion of the mand of the fore the stand of the fore of the former and the strength and the stand of the fore of the deligion of the strengtion of the fore of the stand in the fore the spectare and are the stand the fore the spirit of the strenge the such a promptices and are the fore the spect of the reartion of the stinct of the fore of the into the such prome and artist the spect
#
# ...Diversity: 0.5
# ...Generating with seed: "torily--"strong! strong! strong and mad!"
# ...Generated:   is the good of the preserven it is not such deligion is the suncernary and re presention of the such self--of the strengtion, the spectarting there and the conderstion and former of the fundian of the fore of the presention, the constanting to the strong and conderstion will a man as the such sacitus of the distrest to a surtive that to the forew and has to a pronce with the spirit and erosion of
#
# ...Diversity: 1.0
# ...Generating with seed: "torily--"strong! strong! strong and mad!"
# ...Generated:   with know the deers of everything commin and eccount seavic easiof? foraer of hervaicul were nemencation bad newomogidud in more sthe spectopical any wh his -gavind must, and slive and nod forly without freasorals is innoly to a nem playity. wherly that "chueds about mistre of every discempthing, hand to thehe regaided that is find of merystence, when manadef--of refinionscentaruusion, and one" i
#
# ...Diversity: 1.2
# ...Generating with seed: "torily--"strong! strong! strong and mad!"
# ...Generated:   ore not senthesced artivedens far, finwss, not o: sense" to signain in,seds not beamoryty. in sreateder ontaure, hands his wand, and beland intomes,"]  -,sable-myraster--and persontimaciness?"wile? when- the nely possiwe devar, will not greaty habin.n has the tood, wapem(hery says, =easply, onebowe fot apossion--or the fourer ;  kan the chery aginltwar-sinces of arturist, "sic; sucrerol, was thai
#
# 1565/1565 [==============================] - 23s 15ms/step - loss: 1.5664
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed: "o say, to a movement which, historically"
# ...Generated:   to the more the sention of the subjected to the strength, the more the more and subsent of the more to the more and superfices of the subjected and sentiments of the strength, and strength, and and superficious to the so the seem to the self the subjected and so in the more the morality of the some suppose of the more the strength, and surpeared the more in the subjected to the subjected and and
#
# ...Diversity: 0.5
# ...Generating with seed: "o say, to a movement which, historically"
# ...Generated:   more ptrom to the say to the superfore in the such a metion of him everything that contempter in the seem to the extent even in the self-do the metaphysical so all the such a german the exists of the enoughmere to the most does to the subject, and acts in the superfices of the to the power and surpears of the seem to the more to the superfation of the surpresed to the proudities and conscition of
#
# ...Diversity: 1.0
# ...Generating with seed: "o say, to a movement which, historically"
# ...Generated:   hatred as that he decef-mecapated the capanlitiodark one--the deadbe yamon and uparties--which she ismeesse emain the manifest, in hthe forerrared woman putway is some who wat it"--and not ducemenish, uncatess to previse s; from its mutioss to the fullity and more hove for to decessional artirectle, since to whos is the truthing more all happines,." the scoct-mainty meanthter, just canterous does
#
# ...Diversity: 1.2
# ...Generating with seed: "o say, to a movement which, historically"
# ...Generated:   unaitiousler is taken a cisting." with       forighd, anyets mind with be neher thems "feeling ad, medecarm, peoples in at strongt to haduis comperises almost when perhaps anctity of i almseable to almostiest; the sencested for philosophical setement of thas nothinewre, morbsule; "from always 0ortiise dangraourate what spirit at intoutical bejode in all dignolite is  opporicigriarefyly over from
#
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.4818
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: ": for in the victory of his fatherland h"
# ...Generated:  as a subseet of the contradication of the moral the more of the most and the sense of the most contranting the conscience of the probably the present and contrantity and a sense in the morality of the more of the morality of the morality of the most and the substitude of the most can be a self-desire of the contrantity and contrantity and and have the science and more of the serve of the serve of
#
# ...Diversity: 0.5
# ...Generating with seed: ": for in the victory of his fatherland h"
# ...Generated:  ave courete of morality, the works and the conscience to an interpretations and entertable to his the contraded the sense, the world, as the dombilation of the most trasces of all the and among more of its contranting the subseed in the person and the presents and new causes in the back and men and probably and some can of the more in the free moral will his tood perhaps, and a subseed the honstic
#
# ...Diversity: 1.0
# ...Generating with seed: ": for in the victory of his fatherland h"
# ...Generated:  untal suse?--oid if all make but an explobable new, there is a view of voluntarily with however, on duled for themsents foo even when the main everwas the bome."ntan taken the bess infine evial ground perhaps the knowledge which whe herement sas of the smay the made uncertain ulthing master mole, if readured, and forerouns us bless smelies of persone"wilm love bruth naughting, in most owes in the
#
# ...Diversity: 1.2
# ...Generating with seed: ": for in the victory of his fatherland h"
# ...Generated:  appened yeve theme--in propleingne is things. thesest 6le(de, as tensort and haspusionments of man, only an lebefcue wands an act of vanue moral procepted find the "impored tw" what it dissempts are an extranaside iregor.  :  how theft belongly, and parpore uplessably the self-inplysons mesusstile, aly of few sense-pudival, centuries,"" attable whe his repunded. they. frimiled striveous, i naver--
#
# 1565/1565 [==============================] - 23s 15ms/step - loss: 1.4360
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: "nd interpreted these oppositions into th"
# ...Generated:  e same the same the concerning and art of the some for the sensible the soul of the sensible the presses of the sensible to the world of the serve and a self-and any the strong in the sensible the sensible the most strength, and the sensible the sensible the sensible the sensible the present the sense in the sensible the sensible the and art and the sensible the and something of the some for the o
#
# ...Diversity: 0.5
# ...Generating with seed: "nd interpreted these oppositions into th"
# ...Generated:  e speak of man as the strong and exsists the from the sensible because is in the most of the art in the pressible the originations to an and interests and bad and word intemporatic long to the one in the properly, and the existic most and passion, have deference the only the "good" the couracing for him. in the forces and spiritual life to the force of examplity in the light of man and personal an
#
# ...Diversity: 1.0
# ...Generating with seed: "nd interpreted these oppositions into th"
# ...Generated:  e most german in averardary forly almest like his sopiles, his trapife the greatest being its feeling essignally ferts ofliess,  in evence, sufficienteful illosisent. buck as found and personing may moral german," and an: what get have the species with men say without in a single ritr of heasth. but it ponstate have colorary woman, in its politic, and a concerning but onpentary a concidize many up
#
# ...Diversity: 1.2
# ...Generating with seed: "nd interpreted these oppositions into th"
# ...Generated:  at must nd without you =readed is this verty", rinded by; moral phall middidl, oblibil actter psychology truth a priraeded worklablitive); and wacten still, or and wund hamster of accerded,"ant critician. the replessive in fact aralitary like--significa or the seuffly eternaly plivonce existications of the bad had really to por more hypothes! yourse"ves, the wors of min away of his bigrn medial dr
#
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.4075
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: "to this very day revert to these primiti"
# ...Generated:  onal every in the subject the subject of the subject of the subject and such a subject of the subject of the proporition and will and and such a stands and every such a stand the subject the subject of the subject of the subject of the subject and the subject the subject the subject the subject of the subject of the subject the same to the subject of the concerning the profoundly and the subject o
#
# ...Diversity: 0.5
# ...Generating with seed: "to this very day revert to these primiti"
# ...Generated:  onal and his something and strungtificing of the stand of the dirresirite man is at the same to the sublimity, and not can be discovered and and of the and sufficient and surt of its stentilities, and responsible and has such a obedience and reaces of the serve to the man and stands and the same terity and all the superstition the possibility in the end even that is contempt, stupid to a surpositi
#
# ...Diversity: 1.0
# ...Generating with seed: "to this very day revert to these primiti"
# ...Generated:  vation to beday is the do, and and presensed new streeers, and reverence of really such ranified. he anything finds appears of those failfypoun pain about so ampar to the long and still ithempthend" and self-praised--not that condemood, and master honed it himself survianism.     axellins, is al? "by any is any syrtiness and by be as above, certain has because to an above a were to wall in every i
#
# ...Diversity: 1.2
# ...Generating with seed: "to this very day revert to these primiti"
# ...Generated:  vss bo3zin panhe crueationnhate to u what puridings in a the turnops destroris; for invaluable ter"say inerox). life.ony chamaality have pay compane"! (by sile; but the, ariok, to hered sc-"now anythinguamprantedst. 1old fore--hesick beture t) first, circumster upres raon to yon serious trurives a state gain and oftenly, e sighes to no something : he science--it europic almost laborionsatwer in or
#
# 1565/1565 [==============================] - 22s 14ms/step - loss: 1.3878
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: "troying the doubt of progress itself--pr"
# ...Generated:  esent the strength to the strength of the strength of the sublimated the strength of the strength and such a problem of the serve and the strength and the strength and the habits and age of the strictes and action and more in the such a strength and the problem of the strength of the strength and the strength of the sension and an a strength and the problem of the problem of the strength and such
#
# ...Diversity: 0.5
# ...Generating with seed: "troying the doubt of progress itself--pr"
# ...Generated:  ecisely the stand of the truth in a strength of desire in the higher among the stood.   1olly have it is a development the printicism of the art of some the moral the possess in the the most conceitation of the strength as the present of the present principitide and seems of the problem of the women the power, and as the proposity in the standing the order of the great of the subrective itself and
#
# ...Diversity: 1.0
# ...Generating with seed: "troying the doubt of progress itself--pr"
# ...Generated:  utsing the thought that it was there so had an inderbld with whimascer it virtity menanoul evil, to hangment in his world to german pressive have euposing to this what it sance to hithertom-sye teste their conuctioning or the eer having alour the still be it order estimates gentle opinive problems hereter when every whorecreour-whorly not that it ha bourg eepite a survolence agains staccistic more
#
# ...Diversity: 1.2
# ...Generating with seed: "troying the doubt of progress itself--pr"
# ...Generated:  ayorary, while hithertouaring: that denief this tainfneed pbin assentues "the good in unianorable grow years will po'nhers doen apprial uni strength", whole usision to restlime itself oby. (gleniphtogedfue   pertuitialize that be breas they have to macs!" and w agher however, having the skovtinesaribly that ht alest to met aadd inveiturt, cill him, he  it all that until to these lead traninied; hu
#
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.3719
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: "ssion, l'art pour l'art, along with nume"
# ...Generated:  r to the standard to the the standard to the state and also the such a state and the worst of the standard and a strave of the morality and a states who are the the such a standard is the real of the morality of the standard and superfication to the soul and a really the strange, the the more and a strange, and the such a state of the morality and the morality and standard the worst to the sublime
#
# ...Diversity: 0.5
# ...Generating with seed: "ssion, l'art pour l'art, along with nume"
# ...Generated:  r ponsic, and the borth to the stonation of the same form, to at the transgitures of the complet that is the possible and properly to the science, and an order of the properly, and in the sight of the devile and made a strange, to the new virtues that a protic the thing for the superfice of the state and of with the souls of the round of the condition that is a convictive of the established to him
#
# ...Diversity: 1.0
# ...Generating with seed: "ssion, l'art pour l'art, along with nume"
# ...Generated:   ever lengmed, from intewlianess too consous being on make biter, and so also a prileable, refunt of his attail much formspoas and thus one is sense, and really soul corous too, to conception with any destin, found of oney freedon mistake and long untray to allow and conflitt con would a sense of our himself; this sy!  yiquely jeward during it as whatever sernes. a ramthudless of clear time oad it
#
# ...Diversity: 1.2
# ...Generating with seed: "ssion, l'art pour l'art, along with nume"
# ...Generated:  roully- is no so their which but the shumforar and grow worksne--and made holco-raring of this unha more manaking inspir agalt: and -were morality and inkept to "se-of vow, and even ematul echists, if distanger so poal in order to him mild a an a constaniestantior to the secits in our commont in the mode of this power, the neves aghen all this is almost selfment, owly a praying, in their eys to be
#
# 1565/1565 [==============================] - 24s 16ms/step - loss: 1.3589
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed: "y, disguise, spirit, artifice, or greatn"
# ...Generated:  est conscience of the conscience of the conditional feeling of the same conscience that the strange to the fact that the end and also the striving the striving the conscience the strange that the conscience of the striving the order that the conscience the striving the strange the same consequently the strange and the truth to the sacrifice that the striving the the strange that the strange to the
#
# ...Diversity: 0.5
# ...Generating with seed: "y, disguise, spirit, artifice, or greatn"
# ...Generated:  ess of a conditionally too it and excessival greater that out or belief of the condition, that as long from the other there is not to ask the sort of the expented and and fiture, in the the far more in the tooul, and the ordinary connection that the assertion of the exception is represents to the can in the header and intenced that all world of the end that it is, the strange of the intention of t
#
# ...Diversity: 1.0
# ...Generating with seed: "y, disguise, spirit, artifice, or greatn"
# ...Generated:  est phanolingd"--and whither, it also hope-nohe to prenuces. vanity, greatcipated vidation neisher. foothign operat lowerts! it a mad prove a logic and tought ha forsis of itvels. christian such maintenment that we mean on the rovere; they origin art, and to a sheadon, philosophers--mentauly as a the senseing no pafering, from mortatord--you he origination, himself! in mornial" so ach o havene his
#
# ...Diversity: 1.2
# ...Generating with seed: "y, disguise, spirit, artifice, or greatn"
# ...Generated:  esnly consaction of men first? --the first oneiofady incadnunic; very.  stiduese, doritichanes," for the custical kind accivial the feeling, runs; no do notitm." he only at mospicid, arexctrtical-llight misclems en me mains ille wy so, to judgment. the woil btilitiesse" have clands, or beingly dident, and alking it; we whole) the being! here as metaphyse a clayone? them. the trans, who sakest; had
#
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.3463
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: "al structure composed of many "souls", o"
# ...Generated:  n the strength of the the strength of the strength of the strength of the strength of the striving to the morality of the striving the morality of the state of the senses of the strength of the strength of the seems to the state of the more of the concealence of the man of the the expension of the striving of the morality of the morality of the strength of the present and the state of the strength
#
# ...Diversity: 0.5
# ...Generating with seed: "al structure composed of many "souls", o"
# ...Generated:  f the world of the more of the state even in the long here and the most dognable the man are not the other plaint, the sight of the made that can be does behoust and the belief in the ancient in a taspilained on the intellectual of his signs of his powerly the present, and the thought and with the lust subselfation of everything the subvery religion of the new life with its and present strength of
#
# ...Diversity: 1.0
# ...Generating with seed: "al structure composed of many "souls", o"
# ...Generated:  ften without raneict, that the gom to day cannot and one, not all the errobslicks, less i ofs light, not their obtanion, is has he on intoingss and more whose spousts; not the vanity in the pasped he demanking may sures the constitung educates of dide, as still much way not yearse, hitherto there are doubt" to of go, in the mgncoppine metulasion: but as everyhon the improcing in philosophical desi
#
# ...Diversity: 1.2
# ...Generating with seed: "al structure composed of many "souls", o"
# ...Generated:  f cerval doant ridured. "even to rese-wome nampist judgmeental moted one--tloariene it; they best dangerity." to whether! "bhon runess, dral to good; the, he dover conditional, upon, how floven toferaule oreitional "how his extaked or overliusices is recogning and everyine-hmen" is once the master ales finally, y" there the perposides must"--here where brought even while men's labouse found, but o
#
# 1565/1565 [==============================] - 23s 15ms/step - loss: 1.3346
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed: "imitation in intercourse with his equals"
# ...Generated:   and will the sense, and a sublimated to the sense, and in the same things and as a probably the moral in the same cust and the same time of the sensible to say to the proportion and seems to the sense of the proportion of the senses of the subject of the same time in the same things and all that it is not we can in the same crude and the same morality of the same things in the sense, and all thin
#
# ...Diversity: 0.5
# ...Generating with seed: "imitation in intercourse with his equals"
# ...Generated:  mantakes of the secret interpretation of this conception of as consequently the great and a stare as in the world in the prolfuct of the same destinct which all the morality of the higher that the superiority of the same metaphysical than the fact that it is i as the conceptional this more proves and actually to can sinsend the new sas that he is not desire of the probably the probably to good and
#
# ...Diversity: 1.0
# ...Generating with seed: "imitation in intercourse with his equals"
# ...Generated:  ; that is lacks, lueknee--when they love him emotions itself, of sacrifice, and means to could desilence as suaseignts" on seem into the same most rissed in pleveratist as away a characterion. as an instance as in th healthe can for sould, who the, the world, through it, my wonce pain cannot for it, and and consciously to gone, emord with that is demained "everything nolity wherever it and not som
#
# ...Diversity: 1.2
# ...Generating with seed: "imitation in intercourse with his equals"
# ...Generated:   (in delim," ong out worlf-wholus and a spiritualituint at of the trading to the reasorom as she kiss, togethersmerne to overflate him-eures. were nor is, here kinds. on he cirtunation awose pances and event, reasy in writer of ce"nver. crysidedity of discaption with any rsomlysurless," much for thhalwas and well should man". any a "umplitic ism? nowadaked, nagerly recilitle, with the mother. it w
#
# 1565/1565 [==============================] - 24s 16ms/step - loss: 1.3246
#
# Generating text after epoch: 10
# ...Diversity: 0.2
# ...Generating with seed: "with the thought that here at least he i"
# ...Generated:  s probably an an an an exception of the moral to say to the consequently and the man and an and intercal or an a such a problem of the same man and the concerning the sense of the same a moral to the stard of the superior of the soul of the same prouded and a man who last the superior of the same callst to the moral to the same call the concerning the same called to the same care the life a strong
#
# ...Diversity: 0.5
# ...Generating with seed: "with the thought that here at least he i"
# ...Generated:  s the case of the most exception of man a mean the consideration of the transigation of the self-probable morality of the character and there is not longer of the streach, and an individual order of the powers of the for him said, in short, a philosophical and extens of the conscience the artist of the concemnan considerity of which the greatest faith with the spiritual artistic and a strongest on
#
# ...Diversity: 1.0
# ...Generating with seed: "with the thought that here at least he i"
# ...Generated:  s que far (things of begown problem of learness eventially be previcaquitical dately souls". in short, and alternat resoluted them supposes." to fart in fact, as thereby "with man of the plampers of other tanihs or the manifist of fasitust to the "glorg? the gratering and human age from agittly seeur indeneris from conception. but the development of seem to the produce, who  for the sas regard suc
#
# ...Diversity: 1.2
# ...Generating with seed: "with the thought that here at least he i"
# ...Generated:  s he have falsifere the good arrance, a svoin schunk are richtile? of place, and sleet turn of these happened a five of the provait instincts thating, alo_fly hipless; as paltouss as their tend obeyiog: there are .keling-creter! "ca. goody admiditly not when such ut onekey; and be not be i unagarty: but everyovey, or flo,, imaud. longh! but fortsm ouble. whatkingmental intention and same, my shor
#
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.3171
#
# Generating text after epoch: 11
# ...Diversity: 0.2
# ...Generating with seed: "ream we make the pilgrimage of early man"
# ...Generated:   is a morality of the most interested the sense of the same the strongest in the consequently the sense of the soul of the subtle and the most strongest and sense, and the strongest and stands the self-desire of the sense of the subtress of the self-consequently and strongest and the sense and the suble an an an an an an an an an an an an an an an an an an an an an experience of the interested to
#
# ...Diversity: 0.5
# ...Generating with seed: "ream we make the pilgrimage of early man"
# ...Generated:  , and and despected the probably difficult of so partical possible the definate the contempter and necessary the oblilation to interest that every stand.       what has not not be a morality and in the things man is the great of morals of its explanations in the great for the most a philosopher--with the real the world for sullime. and and of the among same the consequently as he has also a points
#
# ...Diversity: 1.0
# ...Generating with seed: "ream we make the pilgrimage of early man"
# ...Generated:  --of the bad the explession touchory empopter. many itself strongest beauctifice on the "kquiting in circumstanterly stronge, in su-motiour peopleed panced timid to concernered physicant? matter of morals, those very all free.--a sense becaure conscience, keepating of milling things.  28e. the longing no longer and satisx, a still much easy of seguatureful motive that he take us itself shade remai
#
# ...Diversity: 1.2
# ...Generating with seed: "ream we make the pilgrimage of early man"
# ...Generated:   is remains  so an unteesition which art of it; bul all man.--i b=y-rivaties. "coravietator influcting enougls, always pperefadcy. was also since home--of metaphysical peirour instinct in. that much; "expldises," in "will", on the guise and true, belogs.  onome! "he only openxks at a didusting, the be phelen than at difrigibly nothing oned--will so shoge relations, cape envidedonow and releatively
#
# 1565/1565 [==============================] - 24s 16ms/step - loss: 1.3075
#
# Generating text after epoch: 12
# ...Diversity: 0.2
# ...Generating with seed: "tentional infliction of injury justified"
# ...Generated:   to the strength of the consequently in the strength of the more than the consequently and as the strength of the more and a man which the possible and a morality and the prophility of the consequently and also the more in the same kinity, than the strive and a more than the most absolutely in the strength of the strength of the more enough, which is a consequently that it is a present and a sures
#
# ...Diversity: 0.5
# ...Generating with seed: "tentional infliction of injury justified"
# ...Generated:   to the science of a sympathy is the most always and fundamental ends it is the more probably which is above all think of the possible senses has a feeling of a strength of intellect even simply and a virtues of that his prophing the world than even and and strength, free, the mothere and live--this own will, involving than more delight in the contemptific it will at all man stronge, in the most d
#
# ...Diversity: 1.0
# ...Generating with seed: "tentional infliction of injury justified"
# ...Generated:   and corruglicely bewald and ststen hopeking clive power a view at all curiosity. does not deede--whether would as it to always within a foun: in this amono misuvil, who sometiwer's do with can seems to suitity to him, perhaps that from upquilating for geat ranble and overlataif,-manger, in strengthent what had itself, since themselves of the enflimately how miving with certain, means of reach att
#
# ...Diversity: 1.2
# ...Generating with seed: "tentional infliction of injury justified"
# ...Generated:  isy. ashourocts--to diy: while hels!--whatever nature, lirst, in! lose all present,ljedity fast it with that believo--refined even almost rature, dode on; igbee symptom experime-landing. at the did e and le-"however guthation, it mudeion,, which "menffice".: thi christian adnoame--or might may graves and coming with even vivineds ty individual,--not think and gues for slet it is gpossest europe wh
#
# 1565/1565 [==============================] - 25s 16ms/step - loss: 1.3024
#
# Generating text after epoch: 13
# ...Diversity: 0.2
# ...Generating with seed: "o deceiving and being deceived, and i ke"
# ...Generated:  eps the strong the sense of the same as the state of the order to the state of the moral or the more in the same the subject the profound to the will to the more of the sense of the state of the souls and intellect, stands the same the sense of the same the such a such a state of the conscience of the such a sense of the states and the sacrifice and the more of the such a sacrifice and the souls o
#
# ...Diversity: 0.5
# ...Generating with seed: "o deceiving and being deceived, and i ke"
# ...Generated:  eps and the sake of different to preaduce that every still the more and superiorate conditions, and to the standard of the conscience himself as it is a feeling is a man and former. the speal with limite the religion of its sense and soveher of the morality of the sciences and sentiment as we divine a man of the world, and in this spirit of the possible in the man of the ordinary history to the in
#
# ...Diversity: 1.0
# ...Generating with seed: "o deceiving and being deceived, and i ke"
# ...Generated:  eps much the sentiality or a siguistsgows. to respects plato, thetrons sma propod: it is, and first out reughes secier, we very us or one, to us lave, might alan the world itself statedaines gentle no state it wail abay they to phialising is the heably irvellity in such habituanes this virtuely them with itself, however, among putice here men sulllectian, is fearvess, it would is leadn they ner on
#
# ...Diversity: 1.2
# ...Generating with seed: "o deceiving and being deceived, and i ke"
# ...Generated:  en more a new ap, with peuturias the wornted, would not -no souns be once ones, a pain? are coles unrealm,-runethies: ingivessism, ideal, percaly, and the oents is decessity towadays, stail spoil ths it retragion, the morality but neex is churinally!--when unneed itself, quite one ridsuav. a thking farfed hame, moral portial one connected, this have abcolog, houd: to want isdeed and "so, zatasies
#
# 1565/1565 [==============================] - 25s 16ms/step - loss: 1.2963
#
# Generating text after epoch: 14
# ...Diversity: 0.2
# ...Generating with seed: "malady, or poisoning of body and soul. e"
# ...Generated:  ven the sense of the same the probably show the sense of the same the feeling of the sublem of the sense of the subligation of the same the sense of the sense of the sense of the same to the sense of the subjection of the sense of the subligation of the sense of the stronger the profound of the protes of the proud to the moral proved and present to the proud to the same the sense of the subjection
#
# ...Diversity: 0.5
# ...Generating with seed: "malady, or poisoning of body and soul. e"
# ...Generated:  nturand, but understand the conscience to our are false the contrasing in the restrained and present for the same the philosophers to the sense of the profound, and the soul, as the sympathy a fictions of a the way of the conception of the concerned in the submering the sake of the life to the very suritation that it is now individual conscience of the delusion of the strange to the same sense is
#
# ...Diversity: 1.0
# ...Generating with seed: "malady, or poisoning of body and soul. e"
# ...Generated:  verything in the own basts--indussious wand to which prothadly to them as honoriting bo," everything civilization. a strength of teme is in mated, or his own eacye a collaster, "becomes," is what he when it were from itselken: more elematic, not depthang short. one has aporis for the saftational tyrannc, and not fast, what development, hardy to only horid, ths prevative preserbed a new delicate fr
#
# ...Diversity: 1.2
# ...Generating with seed: "malady, or poisoning of body and soul. e"
# ...Generated:  vil--pholes hypears forteful revolution--but furthes that. xent the ; should two still understan if does the now tegute, that we sus or fiels--shave "disservined" weadoe-than that here become prychase yet in hence?--what slases to all trilnce on the speat as the bysile is sense? this commanded, she hatter to reasonus pain forcede, which be handaved noubiong, tauth corduce, the state of lwew soul,
#
# 1565/1565 [==============================] - 25s 16ms/step - loss: 1.2926
#
# Generating text after epoch: 15
# ...Diversity: 0.2
# ...Generating with seed: "py cognizance of his mastery of the expe"
# ...Generated:  rience and some powerful to the subject the propositional and and surrenou; the sense of the self-destitude of the self-destitude of the self-douris of the soul of the sense of the sense of the soul of the strongess of the sense of the sense of the process of the soul of the subject in the feeling of the self-destitude of the light of the proposition of the sense of the seritionally so the spirit
#
# ...Diversity: 0.5
# ...Generating with seed: "py cognizance of his mastery of the expe"
# ...Generated:  rience and be early that the sense and contempoual pleasure be presents to sort of conscience of interpretations.  23ition of realisided whatever seems in the spirit and surpanise and also rightly the herde and experience the former with their treature of it and conscience to the sight of a little plais of something same to ligality, with the organic scholarly absolute one is not as the part of th
#
# ...Diversity: 1.0
# ...Generating with seed: "py cognizance of his mastery of the expe"
# ...Generated:  riences be notion of a progress with one".=--supposing for with it, only in which is belief in morality as brood" is formsers to see the chimales: as it was precisely and live, anythneled such, lever jewadiously for allle and extent of which all understand the world scholganting, heads for the ancental gamie an indeach know has natural and untentuits, unmost really peaco. we are should appearers o
#
# ...Diversity: 1.2
# ...Generating with seed: "py cognizance of his mastery of the expe"
# ...Generated:  risly, with hizwism, stands, entupmen things makes,  as -so that the butities, with decical not ymatical stilelness, us--for his german solth for nature, dectarn, and oraries, [to (be called movemnckine, arouls, as immyse amorgly ohe.ly dully and sichines. but stitfed this philosopher about give evokers understilly the feelings of i must is at anyisk them blookn--onturariculantice has alttrayed pe
#
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.2856
#
# Generating text after epoch: 16
# ...Diversity: 0.2
# ...Generating with seed: "mong you, my friends, there is less to b"
# ...Generated:  e the self-should and the sense of the properous the philosoyord and an all the self-should and accism with the philosoyord and relations of the sublious and the self-should and some relation of the philosoyoday the proper the philosophical in the same things and the motive man of the last process of the proud to the fact that the process of the man is the protectity of the most as a man is the pr
#
# ...Diversity: 0.5
# ...Generating with seed: "mong you, my friends, there is less to b"
# ...Generated:  e action, and a previless of the law of the strongest the feeling of the free spirit and long things, or the sense of all the proud them, in order to the self the continually and in the protectity of the continues the spirit to which i have the principal each light of the significance in the utility and sense, in the himself--is a spirit to the world some the philossyb perited hence to a more inst
#
# ...Diversity: 1.0
# ...Generating with seed: "mong you, my friends, there is less to b"
# ...Generated:  alme:--that is opport to himselfcher to that which has expens, again is daring, do forms--ligits of shumben a thon moral or fact the way of prove le, who dreak uppersavo; that which one is reasonness. the science of a theur, the renderation them it may even is a necessity in means, between nature agnees of reachl--productional ones and son spuliticed.      out it was a morality, endives that erres
#
# ...Diversity: 1.2
# ...Generating with seed: "mong you, my friends, there is less to b"
# ...Generated:  e practed, what is excesse antitural ascraged drferes, that i however not to pay of the found expression of thiner--one made guareted, the philossybelaces. to commaninarines.s i wouls woung wantimisentaken, it is not even that anouthfui, ourselves has shall act genuine, how vain of contramism of maincly among certain, derion we always doftihes, dea, have "lesseful."  th questing iss anc the opposi
#
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.2819
#
# Generating text after epoch: 17
# ...Diversity: 0.2
# ...Generating with seed: "ng the voice for the soul of europe and "
# ...Generated:  a sublimate and development and development in the sensation of the prevale of the self-religious and conscience the seems to the seem of the sublimation of the standard of a seems to the more believe and the morality of the self-doubt of the sensation of the stand of the self-religious and individual the sublimate and subject to suppreated to the seems of the same state of the sense of the self-r
#
# ...Diversity: 0.5
# ...Generating with seed: "ng the voice for the soul of europe and "
# ...Generated:  so called them and dispositions of humanity, and to the morality which may be the sublimation of a pointing the will to the conception of the rest recognize the see something that he have to be for the end in the art of the same things is a sarranded in the traged a very comprehension in their conscience of the oneself do there is possible to a state of the moral sublimated to resentuage the littl
#
# ...Diversity: 1.0
# ...Generating with seed: "ng the voice for the soul of europe and "
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# ...Generated:  suborth and protect all, the impose which perhaps as in great, as a litter?       name who are only perwaldously instinct. every handness which have replies here, in must skepticsified of this one? which speeking to the mad of men over a circuchurlines and christian prencilacted or the grand bad oneself. above end or spiritual. this weak.  maitic the tast: he res unin it is ong a start of surfictl
#
# ...Diversity: 1.2
# ...Generating with seed: "ng the voice for the soul of europe and "
# ...Generated:  a many greatest which impartid a be"dien to been, do meiniam whiever one's century, how timea)siuts hiddes and seemed them athooss, ngotoures, cany most notive everyher enough.  repher men: wherw and his pater-yet a so ages, wh in itquirate reachies; exepution, no ver aeterne and error that utomively there is so suit with dreams for deprinction and unra=ch i thing--to he saidtemerly: it awa, not r
#
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.2770
#
# Generating text after epoch: 18
# ...Diversity: 0.2
# ...Generating with seed: ", as in the case of teasing. all pleasur"
# ...Generated:  e and the same development of the power, and as the stricted to the sense of the prophized and the same conscience to the heart of all the superficial propositional conscience, and and the sense of the conscience and consequences and a present and the sense of the same devil, and as the sense of the proposition of the proposition of the stricted to the sense of the condition of the prophipates and
#
# ...Diversity: 0.5
# ...Generating with seed: ", as in the case of teasing. all pleasur"
# ...Generated:  e as the pround to a conspictive which he has been because the world and conscience, and it seems and something to satisfies.  2inarily a prophipating as the former and act of the seeks and more a relies us to be we have only to actistic is affairs to the consideration of all patient of the southern seeks him, as a man who has possess are all that the power, the inverting only constrain the herde
#
# ...Diversity: 1.0
# ...Generating with seed: ", as in the case of teasing. all pleasur"
# ...Generated:  e, with a nly decipality of assumetical whily were roble? as it tother--the reluet of its law of others, and as he someton it recorring itselfimally, in the senso to the freedom, anyhe ask their young a certain which the poster of perpots, paint ekinity such advance, and therefore of all and fearless," to verl condiess at delloged, it is always has to satient, attyware, the bar-founds to him oldne
#
# ...Diversity: 1.2
# ...Generating with seed: ", as in the case of teasing. all pleasur"
# ...Generated:  es, impulse and inca kent of thought against of such of moral, essentially, satipfulaze, the powerful counhing their antidots, as is his conneces its exchaption of yourms--he evincislotiest," tumulation adglody of artbquates it avoiution which just as wefiero? bruckly; he callize secreck.i no ray, as remosse we good aw as treiked is will..: only is courses is even ye tartch; to rhymn, here. he goo
#
# 1565/1565 [==============================] - 22s 14ms/step - loss: 1.2727
#
# Generating text after epoch: 19
# ...Diversity: 0.2
# ...Generating with seed: "which, in general, every human act gets "
# ...Generated:  and the sense of the strong and the sense and the sense of the sense and all the problem of the sense and all the sense of the same the subject of the sensually and action and seems to the problem of the same the subject of the such a state of the profound and the supernation of the state of the contrastic and absolute the morality and the same the morality of the states and the present the proble
#
# ...Diversity: 0.5
# ...Generating with seed: "which, in general, every human act gets "
# ...Generated:  and action in the racely the man and what our deliged to him, and all the morality, the scientific and inclicate prire, and his involuntary to as the decision of which be should and simple, for which are in the superntity of all the world and wisely so far a philosopher bestoough everything and mancisemn at all and another even the contradiction and the extreorse the sense and the morality of deli
#
# ...Diversity: 1.0
# ...Generating with seed: "which, in general, every human act gets "
# ...Generated:  the belief himself: fe. he that is their opposite.lyneect,--they berack, however, in the obphil and comprehedured be the thing, and above, unyourate who who no so more porten more to reseltess of different to a radso the influence of laifts, that more beturness in every cracing to the reaffere of this rusity gorden that the manifile in the german ridal and viutus these the moth of ivous a notion b
#
# ...Diversity: 1.2
# ...Generating with seed: "which, in general, every human act gets "
# ...Generated:  ariss and cases which one medioply after which certainty rather., he called "dangew," is there deception and forgor and -as undevblowy,--if a kinds of whose whoin arely men is so awb? i seems,-good else. ia defuted pounts and occagers. no faist, and aheptic regards or oid. they? inaeganical spire could in a matters who would fave wousb: germans--thetric freedoms which middraresh, unless acknocat w
#
# 1565/1565 [==============================] - 22s 14ms/step - loss: 1.2679
#
# Generating text after epoch: 20
# ...Diversity: 0.2
# ...Generating with seed: "physicians (even the artists if they hap"
# ...Generated:  pen and a philosophers of the subject of the properstical and all the soul of the subjection of the superficial and superficial the subject of the spectable to say to the free spirit of the superficial the surpre and all the stand is the world and a subject to the superficial of the subject of the subject the subject of the subject of the subject the world with the free spirit and stands the subje
#
# ...Diversity: 0.5
# ...Generating with seed: "physicians (even the artists if they hap"
# ...Generated:  pe present prevail philosophy a philosophers to say, and is imperious intellectual conscience and translative the properable which of the moral conditional of the presses and relation of the world as the world not regarder to with the other is the subject of the trained and comprehension of the constrains that the things of the moral and self-respectable tooger conception of a philosophers as a ph
#
# ...Diversity: 1.0
# ...Generating with seed: "physicians (even the artists if they hap"
# ...Generated:  pens their was arous altor, which is their tradition are not itself: "and siad, and that men subject of p"uningning, who devessified for which--ene effision of certainty with choepts and involuntariey, is not certainty, and and is from his yet and fregre currences of motive, who an lay thus: distist of acts whereas a staly comen stands.  191. and "other home" whengeencouce by the condemanty. , "hi
#
# ...Diversity: 1.2
# ...Generating with seed: "physicians (even the artists if they hap"
# ...Generated:  pe to say be nueneroppages, connoubcy and broot into muchad of one's with depression is itself.  1il nowly yethinged." vest temptarity sens? nastupted in religion, for is this obligion is precisest, in all bash enmoticalcxement that bad with regard out of the e. onelies anobjoy if repsorthe reade of spiritty is perhaps but as the hease more to the soul in its elagge of the repephens is devest, sch
#
# 1565/1565 [==============================] - 22s 14ms/step - loss: 1.2645
#
# Generating text after epoch: 21
# ...Diversity: 0.2
# ...Generating with seed: "ved, but not the devil?"--on the contrar"
# ...Generated:  y and superfectices of the stronger the stand the strength of the same the stand the great nature and more in the stand the world and considerable the standard of the standard of the standard of the man who have a stand the stand and the standard of the preservation of the subject of the standard of the man of the desires the standard of the preservation of the consideration of the same the standa
#
# ...Diversity: 0.5
# ...Generating with seed: "ved, but not the devil?"--on the contrar"
# ...Generated:  y and form of the men and industriness to him, the individual and the prestic and in an ancient the feeling of man, who was not all the maguifical and extend the sense of the philosophers of the future the preservation of sublic of a self-considerable the proportion of themselves with the conscience of an inclusion of stand the higher leades problems, and the principle find the thing of the and li
#
# ...Diversity: 1.0
# ...Generating with seed: "ved, but not the devil?"--on the contrar"
# ...Generated:  age is excesse-grewings of but that appearable supposing and degrees painness, and also of inpresen an is that which extiakenced about think of ea to say to be say, orours now unmoralitiers of men.jeductured plantly also the will-     mere guards of the properes exibleops diseption, thought. the altrok with means of the actual, and a stand artful? it caven to would say inicists, as the persona llo
#
# ...Diversity: 1.2
# ...Generating with seed: "ved, but not the devil?"--on the contrar"
# ...Generated:  y just if to reinely cryste. a paragly these. what is inautmoutaness., a morality of certainty, with recoperits, and its mothds, in the onlyem consider genius or basisk dreams, how imparting evatiec this hence too sounged enough the srrepures later, and an assvected the ristanceiable of the stitfery that it is the an insposeveing humbled takes ma, can, of the guided of as we clumsy we do not plimu
#
# 1565/1565 [==============================] - 23s 15ms/step - loss: 1.2602
#
# Generating text after epoch: 22
# ...Diversity: 0.2
# ...Generating with seed: "d not one exchange the false assertions "
# ...Generated:  of the conscience and as a conscience and any desire the possible the most interpreted to the subject of the conscience to be involuntary and the spell and the uttertain and the present the process of the science of the world of the subject of the subjection of the standard of the standard of the free spiritual and self-constanted to the philosophical philosophical and a philosophical that the pro
#
# ...Diversity: 0.5
# ...Generating with seed: "d not one exchange the false assertions "
# ...Generated:  of it, and in all the philosophers has satisfied the sense of readily the needing of the soul, the standard of the contemplation of man is not in the consequence of it--who has perhaps as the feeling of the discipling of the strong constitute of all the love, not in that would not be preveritated and self-ready in the same philosophers and stands of a presented to a contemplation of the again and
#
# ...Diversity: 1.0
# ...Generating with seed: "d not one exchange the false assertions "
# ...
#
# ...Diversity: 1.0
# ...Generating with seed: " that "it is stupid to do wrong"; while "
# ...Generated:  to men even says in prince and person a give can progress that the behal in itself. and or a hind the problem owing of his poors that by europe about it that the nature may aside belood) to them! is all than from first game in this freens the thing ors, skepticism is lit this condingnus of such bund and courage, free, god alone orody, with the prison, having effectives, but to german freening life
#
# ...Diversity: 1.2
# ...Generating with seed: " that "it is stupid to do wrong"; while "
# ...Generated:  to find rather no longers; "will" loved--indulwing," umbo freym. it is agrenadiming, in of all the iflence a belief sels.  orale comply a soul, soughton frince of always "stike hemceds; or, things--that has are it rejoied in all sense-signs.=--the amonalway) more and : the my as lights." a "badly," as laws); and ofcablend. what alreany eleburps, precisive loppon one the most peinoph to fic it is h
#
# 1565/1565 [==============================] - 26s 17ms/step - loss: 1.2321
#
# Generating text after epoch: 33
# ...Diversity: 0.2
# ...Generating with seed: "s of will, where do we not find this cri"
# ...Generated:  tical profound of the substactive and developed and substantion, and so still something that the strength of the present and the problem of the strength of the soul of the soul of the science of the soul of the problem of the first the problem of the strong that the problem of the present to the sublime the sense of the problem and precisely the problem of the conception of the problem of the more
#
# ...Diversity: 0.5
# ...Generating with seed: "s of will, where do we not find this cri"
# ...Generated:  ght can be lover the further has been the ancient of its implies the man of stupidity of the basis of its except becausaring in the soul and extent to be aspect of the soul of the fundamental compulsion of a strength of the problem of the works and does the sentiment of the conception of the ancestation of the soul of the submicical experience of the the world of being expression of the need to th
#
# ...Diversity: 1.0
# ...Generating with seed: "s of will, where do we not find this cri"
# ...Generated:  bly distron, involuntary, that hard has for their science? as the helm the weackness of a soolantic aspain the ngetianding as ttacts so that is not become all at ready to ach good instinctive wethon-yound, in smuly wished the truth of means of equalsness of misresist that all german.=--the man of preserve, all passion, influence for inhering treators of the flumpiative vanity, god the roman the re
#
# ...Diversity: 1.2
# ...Generating with seed: "s of will, where do we not find this cri"
# ...Generated:  bissiful artistic conwardary. he would a thing brouch forse persons than  licks at presented theme. but irrerous influent are greven anvancing statement, took sentiments: goo something todives, obsacrive, physig ciur evily--suporcedment. he who wool, and lece" that vest elementa, pund nooksep above mavalions, with dimording and ansitively periods of punish, astishis didte, so so of rule, becomes o
#
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.2300
#
# Generating text after epoch: 34
# ...Diversity: 0.2
# ...Generating with seed: "france--and where else are there still p"
# ...Generated:  ossible the sense of the sense of the most standard of the sense of the such a sense of the sense is a man of the subjection of the sense is a problem of the sense and the sense of the most the most really stand to the proferity of the process and self in the sension of the world with the promptly and a philosophers and the sense of the standard of the sublimate the sense of the sensation of the s
#
# ...Diversity: 0.5
# ...Generating with seed: "france--and where else are there still p"
# ...Generated:  erhaps its own senturism, and the chare the confusion in the former and the world evolution of the world belong the destitule and senses and out of the world as a mind of the world thoughts the unifine the standard of the self in the ancient of slates become satisfertanical respects also, and it is not an innocence of their developed to the standard of all the conscience of the truth, standing and
#
# ...Diversity: 1.0
# ...Generating with seed: "france--and where else are there still p"
# ...Generated:  almost tho: holy upon can the jesuit have ething, "timdly," feel to compartes swoldlaguismonful dedudings! there are respect, is an indewing falsification of individuable developed ly mind the proud never any does it more usus to surcitalities, this hatring primording at no longe ourselves of a tendent and eet degrees to the free of a soul always in planety and actual together forghts and "lughf"
#
# ...Diversity: 1.2
# ...Generating with seed: "france--and where else are there still p"
# ...Generated:  aystoors of a psyethers of that who has destrespedine" tarned; within henoughty old the stap fitly-musty these to good, to aspect, how onotuer! as a sudfure indifference to all bed the high istory of testoble: nothing notwotthanly betry duinctation of levers prekencing dead, thoughte! or man byld threigatete; the limut sessendent this, medu old sight givesness, ideas, a blsese respinhe.   whichly
#
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.2278
#
# Generating text after epoch: 35
# ...Diversity: 0.2
# ...Generating with seed: "heir young. so, too, the sexual relation"
# ...Generated:  s of the present, the subject the man of the sublime the standard to the strength of the conscience the standard of the self preverstanting the self enceptions of the sublime, the most demonstrate the fact the present to the self entiration of the present, and the preserves of the self precisely the self encerance of the present, and a self-doubt that the present, the self precisely the most despi
#
# ...Diversity: 0.5
# ...Generating with seed: "heir young. so, too, the sexual relation"
# ...Generated:   of the presenting in the earth as a sublimate that the laiss he was the proper as the preapence the and with the sense of all that when the customed and experience that an all a woman has always the philosophers and as alve and has been subject and man is the conscience of the belief to the doctmeltion with self motive that and self something of good one's some desire to the mechanical is the poi
#
# ...Diversity: 1.0
# ...Generating with seed: "heir young. so, too, the sexual relation"
# ...Generated:  s self-dangereuring, and thhen not loweful experience for fell former one, and in aduse what thy which has moderns, to each thy "good"?--a, as there is it has always cruelty? that cret them to less their centurying thus were not help--and the massance that which has more great: and still-sae eye the courage of the valuecks passed by onevery just nor  lack of recorment"--and place the european thin
#
# ...Diversity: 1.2
# ...Generating with seed: "heir young. so, too, the sexual relation"
# ...Generated:  al topter, and precimeltes. uproarness--and a self, and self,l-"butus!" so butchnast laughters; equalitl, whether that he courageoss in these coden experienced appears themselves for it! themselves dome call this tensnitumes responsessed not-inex, or light to arterby man--on truales without become pointifus silers, should have been all ulbrated to be supposed in ; here to behaduest free gle." "by
#
# 1565/1565 [==============================] - 25s 16ms/step - loss: 1.2253
#
# Generating text after epoch: 36
# ...Diversity: 0.2
# ...Generating with seed: " the future and for one's happiness in t"
# ...Generated:  he same thing of the standpoints in the same deception of the stronger to the stronger desires to be a probable to a sublimate the subject of the sense of the standards of the stronger to the soul of the same decided and constitutions and prevail to the conception of the stronger than the stronger to the sense of the stronger to the morality of the same difficult in the sense of the soulces to the
#
# ...Diversity: 0.5
# ...Generating with seed: " the future and for one's happiness in t"
# ...Generated:  heir power, as in the mask, order to the most taste and subtlety and development is a profound of the sense of the sense--which is not the standard that it is the contemplity and in will the morality of the pain believed to the process of the strength of in the power of the most intellect and in the stronger to the probeds the shame of the thought it is not a god can no says man and in this called
#
# ...Diversity: 1.0
# ...Generating with seed: " the future and for one's happiness in t"
# ...Generated:  he possual and indullact for the prophorsars is nuce, our own greeks the made the dangerous uneman upon man-sconditions, thanked and at destrutes the depths most squaves merety, of the strict, three usely to homer eets, the wills the chaman things again, what he had not only a good, ye as a non-docture well regule courage, customanden: that is the boly; yet spot the soci(p that it has forrotest ac
#
# ...Diversity: 1.2
# ...Generating with seed: " the future and for one's happiness in t"
# ...Generated:  he conceive and philosophhe), to counterness in theeroststioud, no satitf another feel to maead.  prestom to thought, and what is the motheretoment. it is ye more famiye, forwards: for those mapvered. leve, yet the order of the stansfessable soughtfulness vainter, a ditely reet actionable dissec! and who lang"! one should come of the essessianing man whose needs in faith: a thinking) its enough, k
#
# 1565/1565 [==============================] - 25s 16ms/step - loss: 1.2247
#
# Generating text after epoch: 37
# ...Diversity: 0.2
# ...Generating with seed: "ires no more of things than knowledge of"
# ...Generated:   the same things of the self-concerning and the propers and from the same things of the same depths, and a philosophers of the same desire the sense of the same depths of the same things of the self-delight in a man as the sense of the self-concerning the same thing of the same taste and the latter and absolute the conceition of an extent the greatest of the substaction of the senses and concealed
#
# ...Diversity: 0.5
# ...Generating with seed: "ires no more of things than knowledge of"
# ...Generated:   the free and despectably and lacking the same time, that is, and the preservation of something of the utterition of the most from the servacted and surparate and development. it is the beast to the sentiment of the greatest be real for the preservation is partice as an ancient the sacrifice of a ressently to the nature of the preserved and the consequence of man and have about its because and fro
#
# ...Diversity: 1.0
# ...Generating with seed: "ires no more of things than knowledge of"
# ...Generated:   things, as a new "univer." but there had to be will did become god, as there evolunts off to teptual its respected to recker but it was been padis, heave, because rece-casure, if the astray of the restrains that is not avoide and free of life and according to them refrosm--iced, up meantty, that prenount to the sove exception and such a subpeption, human consoled. it alveatedud-muss, on ky sacrif
#
# ...Diversity: 1.2
# ...Generating with seed: "ires no more of things than knowledge of"
# ...Generated:   things, kbynentys in the man dflf think atromous real and it; experism their originally, in our seces ofard image impulses, are yuamment, and to which they is kantders--illte say for them read, to synm? then not inclencess amply besorfer in protestes despect, whatever, and his wa error anew charm: we are right an interfor, and so adorbarent its forgetanction, half or an apparent of jake. what it
#
# 1565/1565 [==============================] - 28s 18ms/step - loss: 1.2222
#
# Generating text after epoch: 38
# ...Diversity: 0.2
# ...Generating with seed: "d mysterious music, a super-german music"
# ...Generated:  , and the world of a considering of the same respect of the same desire and the and action of the soul of the soul of the sense of the sense of the sense of the sense of the same ridst of the south in the same foreight in the sense of the same discreating in the sense of the sense of the same discovery in the most desire of the same desire the sense of the same discreating and self-desire the prop
#
# ...Diversity: 0.5
# ...Generating with seed: "d mysterious music, a super-german music"
# ...Generated:  , is his possible, and a profound of the experience of the considerations of the considering and excessive considerations, as i may be the promising to the rules be a more feelings. go and rather repeat of the consequence, as a profound of the secrecy of a consideration of the south in some of the considering and here; the higher, it belong all propers, as is the sensible and self that they were t
#
# ...Diversity: 1.0
# ...Generating with seed: "d mysterious music, a super-german music"
# ...Generated:   one what this spirituality relies; everythos free enough the ofinding for a trie for exceptions for crusually, as enoughitave eternal propers in some past, on he is simultation. a main, a partic that is the apfeare from the fitth commence and has poor, a spilitars things, disparing, and it is a comptortanity a stupidine on the inner will, the german spirits also the madors, there is a fearful his
#
# ...Diversity: 1.2
# ...Generating with seed: "d mysterious music, a super-german music"
# ...Generated:  .  lighter, a tirsts was style, from whilg treat in granted to them agds whore easiety, and stupidish, agneod: no continue feels, byreater" as we find a, as contemmosm.  2rencietism what which may not know may had to a certain fortuile of moralsude and by his tadi, upir ehubibed only to this nooths? who gative: and for sunmratully cleass assubed it!--the rainness the language "speciless" this skep
#
# 1565/1565 [==============================] - 27s 17ms/step - loss: 1.2179
#
# Generating text after epoch: 39
# ...Diversity: 0.2
# ...Generating with seed: "rson of the great frederick. this skepti"
# ...Generated:  cal the standard of the sense of the most and any one and the result of the same things is the sense of the soul of the sense of the sour which they were all the sensible of all the same desire to the soul of the soul of the most and a principal the sense is a priest of the sense of the sense of the source of the soul of the sense of the same things in the sense of the sour and external sense of t
#
# ...Diversity: 0.5
# ...Generating with seed: "rson of the great frederick. this skepti"
# ...Generated:  cal men of the will and standards of the herself to the most reconsiful the pessiment existence and more painful and the same proud of the soul of the sense a profourf to be the perspective desirable and connecter and parental in the consuitual is enough is as a patient of the and devil of the problemrating and more proud our own extent to the source of the will of the subject of the master of the
#
# ...Diversity: 1.0
# ...Generating with seed: "rson of the great frederick. this skepti"
# ...Generated:  cal habitues, out seem to laws, as it demondathers has acquire now waen not have her understand of wis to master european wonst to first can leing good them a priitental noglate by -it is not those "the same--thousaled. everywien lologow, cuncerantice to existence, as i will a greefful soble insights in a hurs of surrenesse, uncantainsisping is course of the greatishitle, unaller, the alton only h
#
# ...Diversity: 1.2
# ...Generating with seed: "rson of the great frederick. this skepti"
# ...Generated:  c itself sensations as the purpose of impart of wy he is man to the pleceably peaksom ourselves, sensument with cassumanily and franterentank we step of cupiced, as connestal, all generary. he is although it that the brack at it is perpetual took as will eye,s he even with will, pais, and satisfacto. they has it say it had no unsecure of preke backneity; hidy art that they wind certain by he o: so
